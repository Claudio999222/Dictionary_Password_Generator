# %% [markdown]
# **Dictionary Password Generator**
#
#
# This app is designed to test the security of your passwords by attempting a dictionary attack, as done with Kali Linux or other tools.
#
# Passwords are composed of many possible combinations linked to your personal data. In case you are able to penetrate the password you have chosen, you will have to replace it with a more secure one.
#
# It generates more than 100,000 combinations, including special characters.

# %%
import sys 
import json
from json import JSONEncoder
import contextlib
import pickle

nome = input("insert name : ")
cognome = input("insert surname : ")
datad = input ("insert day of birth : ")
datam = input ("insert month of birth : ")
datah1 = input ("insert year of birth (2023) : ")
datah2 = input ("insert year of birth (23) : ")

    
caratteri = ["!","@","#","$","%","^","&","*","(",")","~","`","'"]

nomigen = "nomi.json"
cognomigen = "cognomi.json"
funzionigen = "funzioni.P"



class var_somme():
    def __init__(self, a , b):
        self.a = a
        self.b = b

    def somme1 (self):
        x0 = self.a + datad + datam + datah1
        print(x0)
        for i in caratteri:
            x0_ = x0 + i
            print (x0_)
            x0_ = i + x0
            print (x0_)
        x00 = self.a + datad + datam + datah2
        print(x00)
        for i in caratteri:
            x00_ = x00 + i
            print (x00_)
            x00_ = i + x00
            print (x00_)
        x01 = self.a + datad + datam
        print(x01)
        for i in caratteri:
            x01_ = x01 + i
            print (x01_)
            x01_ = i + x01
            print (x01_)
        x001 = self.a + datad + datam
        print(x001)
        for i in caratteri:
            x001_ = x001 + i
            print (x001_)
            x001_ = i + x001
            print (x001_)
        x1 = self.a + self.b
        print(x1)
        for i in caratteri:
            x1_ = x1 + i
            print (x1_)
            x1_ = i + x1
            print (x1_)
        x11 = self.b + self.a
        print(x11)
        for i in caratteri:
            x11_ = x11 + i
            print (x11_)
            x11_ = i + x11
            print (x11_)
        x2 = self.a + self.b + datad + datam + datah1
        print(x2)
        for i in caratteri:
            x2_ = x2 + i
            print (x2_)
            x2_ = i + x2
            print (x2_)
        x22 = self.b + self.a + datad + datam + datah1
        print(x22)
        for i in caratteri:
            x22_ = x22 + i
            print (x22_)
            x22_ = i + x22
            print (x22_)
        x3 = self.a + self.b + datad + datam + datah2
        print(x3)
        for i in caratteri:
            x3_ = x3 + i
            print (x3_)
            x3_ = i + x3
            print (x3_)
        x33 = self.b + self.a + datad + datam + datah2
        print(x33)
        for i in caratteri:
            x33_ = x33 + i
            print (x33_)
            x33_ = i + x33
            print (x33_)
        x4 = self.a + self.b + datah1 + datam + datad
        print(x4)
        for i in caratteri:
            x4_ = x4 + i
            print (x4_)
            x4_ = i + x4
            print (x4_)
        x44 = self.b + self.a + datah1 + datam + datad
        print(x44)
        for i in caratteri:
            x44_ = x44 + i
            print (x44_)
            x44_ = i + x44
            print (x44_)
        x5 = self.a + self.b + datah2 + datam + datad
        print(x5)
        for i in caratteri:
            x5_ = x5 + i
            print (x5_)
            x5_ = i + x5
            print (x5_)
        x55 = self.b + self.a + datah2 + datam + datad
        print(x55)
        for i in caratteri:
            x55_ = x55 + i
            print (x55_)
            x55_ = i + x55
            print (x55_)
        x6 = self.a + self.b + datam + datad + datah1
        print(x6)
        for i in caratteri:
            x6_ = x6 + i
            print (x6_)
            x6_ = i + x6
            print (x6_)
        x66 = self.b + self.a + datam + datad + datah1
        print(x66)
        for i in caratteri:
            x66_ = x66 + i
            print (x66_)
            x66_ = i + x66
            print (x66_)
        x7 = self.a + self.b + datam + datad + datah2
        print(x7)
        for i in caratteri:
            x7_ = x7 + i
            print (x7_)
            x7_ = i + x7
            print (x7_)
        x77 = self.b + self.a + datam + datad + datah2
        print(x77)
        for i in caratteri:
            x77_ = x77 + i
            print (x77_)
            x77_ = i + x77
            print (x77_)
        x8 = self.a + self.b + datad + datah1 + datam 
        print(x8)
        for i in caratteri:
            x8_ = x8 + i
            print (x8_)
            x8_ = i + x8
            print (x8_)
        x88 = self.b + self.a + datad + datah1 + datam 
        print(x88)
        for i in caratteri:
            x88_ = x88 + i
            print (x88_)
            x88_ = i + x88
            print (x88_)
        x9 = self.a + self.b + datad + datah2 + datam
        print(x9)
        for i in caratteri:
            x9_ = x9 + i
            print (x9_)
            x9_ = i + x9
            print (x9_)
        x99 = self.b + self.a + datad + datah2 + datam
        print(x99)
        for i in caratteri:
            x99_ = x99 + i
            print (x99_)
            x99_ = i + x99
            print (x99_)
        x10 = self.a + self.b + datah1 + datad + datam
        print(x10)
        for i in caratteri:
            x10_ = x10 + i
            print (x10_)
            x10_ = i + x10
            print (x10_)
        x100 = self.b + self.a + datah1 + datad + datam
        print(x100)
        for i in caratteri:
            x100_ = x100 + i
            print (x100_)
            x100_ = i + x100
            print (x100_)
        x11 = self.a + self.b + datah2 + datad + datam 
        print(x11)
        for i in caratteri:
            x11_ = x11 + i
            print (x11_)
            x11_ = i + x11
            print (x11_)
        x110 = self.b + self.a + datah2 + datad + datam
        print(x110)
        for i in caratteri:
            x110_ = x110 + i
            print (x110_)
            x110_ = i + x11
            print (x110_)
        x12 = self.a + self.b + datam + datah1 + datad
        print(x12)
        for i in caratteri:
            x12_ = x12 + i
            print (x12_)
            x12_ = i + x12
            print (x12_)
        x120 = self.b + self.a + datam + datah1 + datad
        print(x120)
        for i in caratteri:
            x120_ = x120 + i
            print (x120_)
            x120_ = i + x120
            print (x120_)
        x13 = self.a + self.b + datam + datah2 + datad
        print(x13)
        for i in caratteri:
            x13_ = x13 + i
            print (x13_)
            x13_ = i + x13
            print (x13_)
        x130 = self.b + self.a + datam + datah2 + datad
        print(x130)
        for i in caratteri:
            x130_ = x130 + i
            print (x130_)
            x130_ = i + x130
            print (x130_)

        x12 = self.a + self.b + datah1
        print(x12)
        for i in caratteri:
            x12_ = x12 + i
            print (x12_)
            x12_ = i + x12
            print (x12_)
        x120 = self.b + self.a + datah1 
        print(x120)
        for i in caratteri:
            x120_ = x120 + i
            print (x120_)
            x120_ = i + x120
            print (x120_)
        x13 = self.a + self.b + datah2 
        print(x13)
        for i in caratteri:
            x13_ = x13 + i
            print (x13_)
            x13_ = i + x13
            print (x13_)
        x130 = self.b + self.a + datah2 
        print(x130)
        for i in caratteri:
            x130_ = x130 + i
            print (x130_)
            x130_ = i + x130
            print (x130_)


with open('loddoni.txt', 'w') as f:
    with contextlib.redirect_stdout(f):
        for i in nome:
            diz = var_somme(i, cognome)
            diz.somme1()
            diz = var_somme(i.upper(), cognome)
            diz.somme1()
            diz = var_somme(i, cognome.upper())
            diz.somme1()
            diz = var_somme(i[0], cognome)
            diz.somme1()
            diz = var_somme(i[0].upper(), cognome)
            diz.somme1()
            diz = var_somme(i[0], cognome.upper())
            diz.somme1()


        for i in cognome:
            diz = var_somme(i, nome)
            diz.somme1()
            diz = var_somme(i.upper(), nome)
            diz.somme1()
            diz = var_somme(i, nome.upper())
            diz.somme1()
            diz = var_somme(i[0], nome)
            diz.somme1()
            diz = var_somme(i[0].upper(), nome)
            diz.somme1()
            diz = var_somme(i[0], nome.upper())
            diz.somme1()


        with open(cognomigen,"r") as libreria_cognomi1:
            cognomi123 = json.load(libreria_cognomi1)
            for i in cognomi123.values():
                if i == "" :
                    break
                else:
                    diz = var_somme(nome, i)
                    diz.somme1()


        with open(nomigen, "r") as libreria_nomi1:
            nomi123 = json.load(libreria_nomi1)
            for i in nomi123.values():
                if i == "" :
                    break
                else:
                    diz = var_somme(cognome, i)
                    diz.somme1()

            for i in cognomi123.values():
                if i == "" :
                    break
                else:
                    for x in nomi123.values():
                        if x == "" :
                            break
                        else:
                            diz = var_somme(i,x)
                            diz.somme1()



        diz = var_somme(nome, cognome)
        diz.somme1()
        diz = var_somme(cognome, nome)
        diz.somme1()
